# %% [markdown]
# ## Hamiltonian CNN?

# %%
import os as os
import numpy as np
import sklearn.datasets as datasets
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.model_selection import train_test_split
import torch.utils.data as data_utils
from torchdiffeq import odeint
from torchsummary import summary
import torchvision as torchvision

from torchcontrol.arch_cpugpu import HDNN
from torchcontrol.predictors import MLP, CNN
from torchcontrol.utils import genpoints, dump_tensors

#MNIST imports
import torchvision.transforms as transforms
import torchvision.datasets as dset

# %%
dump_tensors()
# Out:
# Total size: 0

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
root = './data'
if not os.path.exists(root):
    os.mkdir(root)
    
trans = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (1.0,))])
# if not exist, download mnist dataset
train_set = dset.MNIST(root=root, train=True, transform=trans, download=True)
test_set = dset.MNIST(root=root, train=False, transform=trans, download=True)

batch_size = len(train_set)

trainloader = torch.utils.data.DataLoader(
                 dataset=train_set,
                 batch_size=10000,
                 shuffle=True)
testloader = torch.utils.data.DataLoader(
                dataset=test_set,
                batch_size=10000,
                shuffle=False)

# %%
d = iter(testloader)

# %%
x = next(d)

# %%
x[0].shape
# Out:
# torch.Size([10000, 1, 28, 28])

# %% [markdown]
# ## CNN model

# %%
class CNN(nn.Module):
    def __init__(self, conv_layers, dense_layers, smax_l = True):
        '''
        smax_l: leave True for softmax applied to ouput
        '''
        super().__init__()
        self.conv_layers = nn.ModuleList([nn.Conv1d(conv_layers[i], conv_layers[i + 1], kernel_size = 3) 
                                     for i in range(len(conv_layers) - 1)])
        self.dense_layers = nn.ModuleList([nn.Linear(dense_layers[i], dense_layers[i + 1]) 
                                     for i in range(len(dense_layers) - 1)])

        self.max = nn.MaxPool1d(2)
        #self.smax = smax_l
        #self.bn = nn.ModuleList([nn.BatchNorm1d(conv_layers[i]) for i in range(len(conv_layers)-1)])
        
    def forward(self, x):
        x = x[0].view(x.size(0), 1, -1)
        for i,l in enumerate(self.conv_layers):
            x = l(x)
            #x = self.bn[i](x)
            x = F.relu(x)
            x = self.max(x)
        x = x.view(x.size(0), -1)
        for l in self.dense_layers:
            l_x = l(x)
            x = F.relu(l_x)
        if self.smax: return F.log_softmax(l_x, dim=-1)
        else: return torch.sigmoid(l_x)

# %% [markdown]
# ## HCNN

# %%
m = HDNN('CNN',[[1,3,5],[3900,10]],[1,2,0],1,'cpu').to(device)

# %%
m.predictor
# Out:
# CNN(
#   (conv_layers): ModuleList(
#     (0): Conv1d(1, 3, kernel_size=(3,), stride=(1,))
#     (1): Conv1d(3, 5, kernel_size=(3,), stride=(1,))
#   )
#   (dense_layers): ModuleList(
#     (0): Linear(in_features=3900, out_features=10, bias=True)
#   )
#   (max): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# )

# %%
summary(m.predictor,(1,1,28*28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv1d-1               [-1, 3, 782]              12
#             Conv1d-2               [-1, 5, 780]              50
#             Linear-3                   [-1, 10]          39,010
# ================================================================
# Total params: 39,072
# Trainable params: 39,072
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.05
# Params size (MB): 0.15
# Estimated Total Size (MB): 0.20
# ----------------------------------------------------------------

# %%
m.predictor.state_dict()
# Out:
# OrderedDict([('conv_layers.0.weight', tensor([[[ 0.1813, -0.4917,  0.2969]],
#
#                       [[ 0.2819,  0.4856, -0.4259]],
#
#                       [[ 0.0112, -0.2719,  0.0653]]], device='cuda:0')),
#              ('conv_layers.0.bias',
#               tensor([-0.5022, -0.2418, -0.2881], device='cuda:0')),
#              ('conv_layers.1.weight', tensor([[[-0.2179, -0.0615,  0.1609],
#                        [-0.2973,  0.2313,  0.1312],
#                        [ 0.1769,  0.0275,  0.0111]],
#
#                       [[-0.1518,  0.2178, -0.1435],
#                        [ 0.0569, -0.1953,  0.2118],
#                        [-0.1228, -0.2317,  0.1804]],
#
#                       [[ 0.0130, -0.1297, -0.0028],
#                        [-0.2641, -0.1492,  0.1353],
#                        [-0.3276,  0.0714,  0.2682]],
#
#                       [[ 0.1062,  0.1043, -0.1449],
#                        [ 0.2639, -0.3310, -0.0120],
#                        [-0.2339,  0.0282,  0.0320]],
#
#                       [[-0.0645,  0.2222, -0.2414],
#                        [ 0.2320, -0.0169,  0.3294],
#                        [ 0.0437, -0.1974, -0.1285]],
#
#                       [[-0.0077, -0.2235, -0.0565],
#                        [-0.0689,  0.1157,  0.1350],
#                        [-0.3226,  0.0503,  0.0632]],
#
#                       [[-0.0921,  0.1090,  0.2618],
#                        [ 0.1381,  0.0140,  0.1884],
#                        [-0.0842, -0.1325, -0.2123]],
#
#                       [[ 0.1663,  0.0558,  0.1273],
#                        [ 0.1159,  0.0455, -0.1748],
#                        [ 0.1562, -0.2679,  0.0533]]], device='cuda:0')),
#              ('conv_layers.1.bias',
#               tensor([ 0.2263,  0.3081,  0.0303,  0.1583, -0.1072,  0.3033, -0.1710,  0.2047],
#                      device='cuda:0')),
#              ('dense_layers.0.weight',
#               tensor([[-0.0103, -0.0120,  0.0087,  ...,  0.0096, -0.0025,  0.0086],
#                       [ 0.0042, -0.0093,  0.0026,  ...,  0.0035, -0.0038, -0.0081],
#                       [ 0.0085,  0.0100,  0.0030,  ..., -0.0111, -0.0015, -0.0111],
#                       ...,
#                       [ 0.0124,  0.0071, -0.0022,  ...,  0.0035, -0.0037, -0.0046],
#                       [ 0.0092, -0.0016,  0.0120,  ..., -0.0017, -0.0118, -0.0110],
#                       [-0.0103, -0.0021, -0.0004,  ...,  0.0062, -0.0066,  0.0039]],
#                      device='cuda:0')),
#              ('dense_layers.0.bias',
#               tensor([ 0.0032, -0.0010,  0.0112, -0.0018, -0.0050, -0.0044,  0.0055,  0.0052,
#                        0.0093,  0.0073], device='cuda:0'))])

# %% [markdown]
# ## Hope and dreams

# %%
print('Initial accuracy on training dataset: {} %'.format(m.pred_accuracy(trainloader)))
# Out:
# Initial accuracy on training dataset: 0.0987 %

# %%
m.fit(trainloader,3,time_delta=None,iter_accuracy=20,ode_t=10,ode_step=2)
# Out:
# odeint iter: 10
# odeint iter: 20
# odeint iter: 30
# odeint iter: 40
# odeint iter: 50
# odeint iter: 60
# odeint iter: 70
# odeint iter: 80
# odeint iter: 90
# odeint iter: 100
# odeint iter: 110
# odeint iter: 120
# odeint iter: 130
# odeint iter: 140
# odeint iter: 150
# odeint iter: 160
# odeint iter: 170
# odeint iter: 180
# odeint iter: 190
# odeint iter: 200
# odeint iter: 210
# odeint iter: 220
# odeint iter: 230
# odeint iter: 240
# odeint iter: 250
# odeint iter: 260
# odeint iter: 270
# odeint iter: 280
# odeint iter: 290
# odeint iter: 300
# odeint iter: 310
# odeint iter: 320
# odeint iter: 330
# odeint iter: 340
# odeint iter: 350
# odeint iter: 360
# odeint iter: 370
# odeint iter: 380
# odeint iter: 390
# odeint iter: 400
# odeint iter: 410
# odeint iter: 420
# odeint iter: 430
# odeint iter: 440
# odeint iter: 450
# odeint iter: 460
# odeint iter: 470
# odeint iter: 480
# odeint iter: 490
# odeint iter: 500
# odeint iter: 510
# odeint iter: 520
# odeint iter: 530
# odeint iter: 540
# odeint iter: 550
# odeint iter: 560
# odeint iter: 570
# odeint iter: 580
# odeint iter: 590
# odeint iter: 600
# odeint iter: 610
# odeint iter: 620
# odeint iter: 630
# odeint iter: 640
# odeint iter: 650
# odeint iter: 660
# odeint iter: 670
# odeint iter: 680
# odeint iter: 690
# odeint iter: 700
# odeint iter: 710
# odeint iter: 720
# odeint iter: 730
# odeint iter: 740
# odeint iter: 750
# odeint iter: 760
# odeint iter: 770
# odeint iter: 780
# odeint iter: 790
# odeint iter: 800
# odeint iter: 810
# odeint iter: 820
# odeint iter: 830
# odeint iter: 840
# odeint iter: 850
# odeint iter: 860
# odeint iter: 870
# odeint iter: 880
# odeint iter: 890
# odeint iter: 900
# odeint iter: 910
# odeint iter: 920
# odeint iter: 930
# odeint iter: 940
# odeint iter: 950
# odeint iter: 960
# odeint iter: 970
# odeint iter: 980
# odeint iter: 990
# odeint iter: 1000
# odeint iter: 1010
# odeint iter: 1020
# odeint iter: 1030
# odeint iter: 1040
# odeint iter: 1050
# odeint iter: 1060
# odeint iter: 1070
# odeint iter: 1080
# odeint iter: 1090
# odeint iter: 1100
# odeint iter: 1110
# odeint iter: 1120
# odeint iter: 1130
# odeint iter: 1140
# odeint iter: 1150
# odeint iter: 1160
# odeint iter: 1170
# odeint iter: 1180
# odeint iter: 1190
# odeint iter: 1200
# odeint iter: 1210
# odeint iter: 1220
# odeint iter: 1230
# odeint iter: 1240
# odeint iter: 1250
# odeint iter: 1260
# odeint iter: 1270
# odeint iter: 1280
# odeint iter: 1290
# odeint iter: 1300
# odeint iter: 1310
# odeint iter: 1320
# odeint iter: 1330
# odeint iter: 1340
# odeint iter: 1350
# odeint iter: 1360
# odeint iter: 1370
# odeint iter: 1380
# odeint iter: 1390
# odeint iter: 1400
# odeint iter: 1410
# odeint iter: 1420
# odeint iter: 1430
# odeint iter: 1440
# odeint iter: 1450
# odeint iter: 1460
# odeint iter: 1470
# odeint iter: 1480
# odeint iter: 1490
# odeint iter: 1500
# odeint iter: 1510
# odeint iter: 1520
# odeint iter: 1530
# odeint iter: 1540
# odeint iter: 1550
# odeint iter: 1560
# odeint iter: 1570
# odeint iter: 1580
# odeint iter: 1590
# odeint iter: 1600
# odeint iter: 1610
# odeint iter: 1620
# odeint iter: 1630
# odeint iter: 1640
# odeint iter: 1650
# odeint iter: 1660
# odeint iter: 1670
# odeint iter: 1680
# odeint iter: 1690
# odeint iter: 1700
# odeint iter: 1710
# odeint iter: 1720
# odeint iter: 1730
# odeint iter: 1740
# odeint iter: 1750
# odeint iter: 1760
# odeint iter: 1770
# odeint iter: 1780
# odeint iter: 1790
# odeint iter: 1800
# odeint iter: 1810
# odeint iter: 1820
# odeint iter: 1830
# odeint iter: 1840
# odeint iter: 1850
# odeint iter: 1860
# odeint iter: 1870
# odeint iter: 1880
# odeint iter: 1890
# odeint iter: 1900
# odeint iter: 1910
# odeint iter: 1920
# odeint iter: 1930
# odeint iter: 1940
# odeint iter: 1950
# odeint iter: 1960
# odeint iter: 1970
# odeint iter: 1980
# odeint iter: 1990
# odeint iter: 2000
# odeint iter: 2010
# odeint iter: 2020
# odeint iter: 2030
# odeint iter: 2040
# odeint iter: 2050
# odeint iter: 2060
# odeint iter: 2070
# odeint iter: 2080
# odeint iter: 2090
# odeint iter: 2100
# odeint iter: 2110
# odeint iter: 2120
# odeint iter: 2130
# odeint iter: 2140
# odeint iter: 2150
# odeint iter: 2160
# odeint iter: 2170
# odeint iter: 2180
# odeint iter: 2190
# odeint iter: 2200
# odeint iter: 2210
# odeint iter: 2220
# odeint iter: 2230
# odeint iter: 2240
# odeint iter: 2250
# odeint iter: 2260
# odeint iter: 2270
# odeint iter: 2280
# odeint iter: 2290
# odeint iter: 2300
# odeint iter: 2310
# odeint iter: 2320
# odeint iter: 2330
# odeint iter: 2340
# odeint iter: 2350
# odeint iter: 2360
# odeint iter: 2370
# odeint iter: 2380
# odeint iter: 2390
# odeint iter: 2400
# odeint iter: 2410
# odeint iter: 2420
# odeint iter: 2430
# odeint iter: 2440
# odeint iter: 2450
# odeint iter: 2460
# odeint iter: 2470
# odeint iter: 2480
# odeint iter: 2490
# odeint iter: 2500
# odeint iter: 2510
# odeint iter: 2520
# odeint iter: 2530
# odeint iter: 2540
# odeint iter: 2550
# odeint iter: 2560
# odeint iter: 2570
# odeint iter: 2580
# odeint iter: 2590
# odeint iter: 2600
# odeint iter: 2610
# odeint iter: 2620
# odeint iter: 2630
# odeint iter: 2640
# odeint iter: 2650
# odeint iter: 2660
# odeint iter: 2670
# odeint iter: 2680
# odeint iter: 2690
# odeint iter: 2700
# odeint iter: 2710
# odeint iter: 2720
# odeint iter: 2730
# odeint iter: 2740
# odeint iter: 2750
# odeint iter: 2760
# odeint iter: 2770
# odeint iter: 2780
# odeint iter: 2790
# odeint iter: 2800
# odeint iter: 2810
# odeint iter: 2820
# odeint iter: 2830
# odeint iter: 2840
# odeint iter: 2850
# odeint iter: 2860
# odeint iter: 2870
# odeint iter: 2880
# odeint iter: 2890
# odeint iter: 2900
# odeint iter: 2910
# odeint iter: 2920
# odeint iter: 2930
# odeint iter: 2940
# odeint iter: 2950
# odeint iter: 2960
# odeint iter: 2970
# odeint iter: 2980
# odeint iter: 2990
# odeint iter: 3000
# odeint iter: 3010
# odeint iter: 3020
# odeint iter: 3030
# odeint iter: 3040
# odeint iter: 3050
# odeint iter: 3060
# odeint iter: 3070
# odeint iter: 3080
# odeint iter: 3090
# odeint iter: 3100
# odeint iter: 3110
# odeint iter: 3120
# odeint iter: 3130
# odeint iter: 3140
# odeint iter: 3150
# odeint iter: 3160
# odeint iter: 3170
# odeint iter: 3180
# odeint iter: 3190
# odeint iter: 3200
# odeint iter: 3210
# odeint iter: 3220
# odeint iter: 3230
# odeint iter: 3240
# odeint iter: 3250
# odeint iter: 3260
# odeint iter: 3270
# odeint iter: 3280
# odeint iter: 3290
# odeint iter: 3300
# odeint iter: 3310
# odeint iter: 3320
# odeint iter: 3330
# odeint iter: 3340
# odeint iter: 3350
# odeint iter: 3360
# odeint iter: 3370
# odeint iter: 3380
# odeint iter: 3390
# odeint iter: 3400
# odeint iter: 3410
# odeint iter: 3420
# odeint iter: 3430
# odeint iter: 3440
# odeint iter: 3450
# odeint iter: 3460
# odeint iter: 3470
# odeint iter: 3480
# odeint iter: 3490
# odeint iter: 3500
# odeint iter: 3510
# odeint iter: 3520
# odeint iter: 3530
# odeint iter: 3540
# odeint iter: 3550
# odeint iter: 3560
# odeint iter: 3570
# odeint iter: 3580
# odeint iter: 3590
# odeint iter: 3600
# odeint iter: 3610
# odeint iter: 3620
# odeint iter: 3630
# odeint iter: 3640
# odeint iter: 3650
# odeint iter: 3660
# odeint iter: 3670
# odeint iter: 3680
# odeint iter: 3690
# odeint iter: 3700
# odeint iter: 3710
# odeint iter: 3720
# odeint iter: 3730
# odeint iter: 3740
# odeint iter: 3750
# odeint iter: 3760
# odeint iter: 3770
# odeint iter: 3780
# odeint iter: 3790
# odeint iter: 3800
# odeint iter: 3810
# odeint iter: 3820
# odeint iter: 3830
# odeint iter: 3840
# odeint iter: 3850
# odeint iter: 3860
# odeint iter: 3870
# odeint iter: 3880
# odeint iter: 3890
# odeint iter: 3900
# odeint iter: 3910
# odeint iter: 3920
# odeint iter: 3930
# odeint iter: 3940
# odeint iter: 3950
# odeint iter: 3960
# odeint iter: 3970
# odeint iter: 3980
# odeint iter: 3990
# odeint iter: 4000
# odeint iter: 4010
# odeint iter: 4020
# odeint iter: 4030
# odeint iter: 4040
# odeint iter: 4050
# odeint iter: 4060
# odeint iter: 4070
# odeint iter: 4080
# odeint iter: 4090
# odeint iter: 4100
# odeint iter: 4110
# odeint iter: 4120
# odeint iter: 4130
# odeint iter: 4140
# odeint iter: 4150
# odeint iter: 4160
# odeint iter: 4170
# odeint iter: 4180
# odeint iter: 4190
# odeint iter: 4200
# odeint iter: 4210
# odeint iter: 4220
# odeint iter: 4230
# odeint iter: 4240
# odeint iter: 4250
# odeint iter: 4260
# odeint iter: 4270
# odeint iter: 4280
# odeint iter: 4290
# odeint iter: 4300
# odeint iter: 4310
# odeint iter: 4320
# odeint iter: 4330
# odeint iter: 4340
# odeint iter: 4350
# odeint iter: 4360
# odeint iter: 4370
# odeint iter: 4380
# odeint iter: 4390
# odeint iter: 4400
# odeint iter: 4410
# odeint iter: 4420
# odeint iter: 4430
# odeint iter: 4440
# odeint iter: 4450
# odeint iter: 4460
# odeint iter: 4470
# odeint iter: 4480
# odeint iter: 4490
# odeint iter: 4500
# odeint iter: 4510
# odeint iter: 4520
# odeint iter: 4530
# odeint iter: 4540
# odeint iter: 4550
# odeint iter: 4560
# odeint iter: 4570
# odeint iter: 4580
# odeint iter: 4590
# odeint iter: 4600
# odeint iter: 4610
# odeint iter: 4620
# odeint iter: 4630
# odeint iter: 4640
# odeint iter: 4650
# odeint iter: 4660
# odeint iter: 4670
# odeint iter: 4680
# odeint iter: 4690
# odeint iter: 4700
# odeint iter: 4710
# odeint iter: 4720
# odeint iter: 4730
# odeint iter: 4740
# odeint iter: 4750
# odeint iter: 4760
# odeint iter: 4770
# odeint iter: 4780
# odeint iter: 4790
# odeint iter: 4800
# odeint iter: 4810
# odeint iter: 4820
# odeint iter: 4830
# odeint iter: 4840
# odeint iter: 4850
# odeint iter: 4860
# odeint iter: 4870
# odeint iter: 4880
# odeint iter: 4890
# odeint iter: 4900
# odeint iter: 4910
# odeint iter: 4920
# odeint iter: 4930
# odeint iter: 4940
# odeint iter: 4950
# odeint iter: 4960
# odeint iter: 4970
# odeint iter: 4980
# odeint iter: 4990
# odeint iter: 5000
# odeint iter: 5010
# odeint iter: 5020
# odeint iter: 5030
# odeint iter: 5040
# odeint iter: 5050
# odeint iter: 5060
# odeint iter: 5070
# odeint iter: 5080
# odeint iter: 5090
# odeint iter: 5100
# odeint iter: 5110
# odeint iter: 5120
# odeint iter: 5130
# odeint iter: 5140
# odeint iter: 5150
# odeint iter: 5160
# odeint iter: 5170
# odeint iter: 5180
# odeint iter: 5190
# odeint iter: 5200
# odeint iter: 5210
# odeint iter: 5220
# odeint iter: 5230
# odeint iter: 5240
# odeint iter: 5250
# odeint iter: 5260
# odeint iter: 5270
# odeint iter: 5280
# odeint iter: 5290
# odeint iter: 5300
# odeint iter: 5310
# odeint iter: 5320
# odeint iter: 5330
# odeint iter: 5340
# odeint iter: 5350
# odeint iter: 5360
# odeint iter: 5370
# odeint iter: 5380
# odeint iter: 5390
# odeint iter: 5400
# odeint iter: 5410
# odeint iter: 5420
# odeint iter: 5430
# odeint iter: 5440
# odeint iter: 5450
# odeint iter: 5460
# odeint iter: 5470
# odeint iter: 5480
# odeint iter: 5490
# odeint iter: 5500
# odeint iter: 5510
# odeint iter: 5520
# odeint iter: 5530
# odeint iter: 5540
# odeint iter: 5550
# odeint iter: 5560
# odeint iter: 5570
# odeint iter: 5580
# odeint iter: 5590
# odeint iter: 5600
# odeint iter: 5610
# odeint iter: 5620
# odeint iter: 5630
# odeint iter: 5640
# odeint iter: 5650
# odeint iter: 5660
# odeint iter: 5670
# odeint iter: 5680
# odeint iter: 5690
# odeint iter: 5700
# odeint iter: 5710
# odeint iter: 5720
# odeint iter: 5730
# odeint iter: 5740
# odeint iter: 5750
# odeint iter: 5760
# odeint iter: 5770
# odeint iter: 5780
# odeint iter: 5790
# odeint iter: 5800
# odeint iter: 5810
# odeint iter: 5820
# odeint iter: 5830
# odeint iter: 5840
# odeint iter: 5850
# odeint iter: 5860
# odeint iter: 5870
# odeint iter: 5880
# odeint iter: 5890
# odeint iter: 5900
# odeint iter: 5910
# odeint iter: 5920
# odeint iter: 5930
# odeint iter: 5940
# odeint iter: 5950
# odeint iter: 5960
# odeint iter: 5970
# odeint iter: 5980
# odeint iter: 5990
# odeint iter: 6000
# odeint iter: 6010
# odeint iter: 6020
# odeint iter: 6030
# odeint iter: 6040
# odeint iter: 6050
# odeint iter: 6060
# odeint iter: 6070
# odeint iter: 6080
# odeint iter: 6090
# odeint iter: 6100
# odeint iter: 6110
# odeint iter: 6120
# odeint iter: 6130
# odeint iter: 6140
# odeint iter: 6150
# odeint iter: 6160
# odeint iter: 6170
# odeint iter: 6180
# odeint iter: 6190
# odeint iter: 6200
# odeint iter: 6210
# odeint iter: 6220
# odeint iter: 6230
# odeint iter: 6240
# odeint iter: 6250
# odeint iter: 6260
# odeint iter: 6270
# odeint iter: 6280
# odeint iter: 6290
# odeint iter: 6300
# odeint iter: 6310
# odeint iter: 6320
# odeint iter: 6330
# odeint iter: 6340
# odeint iter: 6350
# odeint iter: 6360
# odeint iter: 6370
# odeint iter: 6380
# odeint iter: 6390
# odeint iter: 6400
# odeint iter: 6410
# odeint iter: 6420
# odeint iter: 6430
# odeint iter: 6440
# odeint iter: 6450
# odeint iter: 6460
# odeint iter: 6470
# odeint iter: 6480
# odeint iter: 6490
# odeint iter: 6500
# odeint iter: 6510
# odeint iter: 6520
# odeint iter: 6530
# odeint iter: 6540
# odeint iter: 6550
# odeint iter: 6560
# odeint iter: 6570
# odeint iter: 6580
# odeint iter: 6590
# odeint iter: 6600
# odeint iter: 6610
# odeint iter: 6620
# odeint iter: 6630
# odeint iter: 6640
# odeint iter: 6650
# odeint iter: 6660
# odeint iter: 6670
# odeint iter: 6680
# odeint iter: 6690
# odeint iter: 6700
# odeint iter: 6710
# odeint iter: 6720
# odeint iter: 6730
# odeint iter: 6740
# odeint iter: 6750
# odeint iter: 6760
# odeint iter: 6770
# odeint iter: 6780
# odeint iter: 6790
# odeint iter: 6800
# odeint iter: 6810
# odeint iter: 6820
# odeint iter: 6830
# odeint iter: 6840
# odeint iter: 6850
# odeint iter: 6860
# odeint iter: 6870
# odeint iter: 6880
# odeint iter: 6890
# odeint iter: 6900
# odeint iter: 6910
# odeint iter: 6920
# odeint iter: 6930
# odeint iter: 6940
# odeint iter: 6950
# odeint iter: 6960
# odeint iter: 6970
# odeint iter: 6980
# odeint iter: 6990
# odeint iter: 7000
# odeint iter: 7010
# odeint iter: 7020
# odeint iter: 7030
# odeint iter: 7040
# odeint iter: 7050
# odeint iter: 7060
# odeint iter: 7070
# odeint iter: 7080
# odeint iter: 7090
# odeint iter: 7100
# odeint iter: 7110
# odeint iter: 7120
# odeint iter: 7130
# odeint iter: 7140
# odeint iter: 7150
# odeint iter: 7160
# odeint iter: 7170
# odeint iter: 7180
# odeint iter: 7190
# odeint iter: 7200
# odeint iter: 7210
# odeint iter: 7220
# odeint iter: 7230
# odeint iter: 7240
# odeint iter: 7250
# odeint iter: 7260
# odeint iter: 7270
# odeint iter: 7280
# odeint iter: 7290
# odeint iter: 7300
# odeint iter: 7310
# odeint iter: 7320
# odeint iter: 7330
# odeint iter: 7340
# odeint iter: 7350
# odeint iter: 7360
# odeint iter: 7370
# odeint iter: 7380
# odeint iter: 7390
# odeint iter: 7400
# odeint iter: 7410
# odeint iter: 7420
# odeint iter: 7430
# odeint iter: 7440
# odeint iter: 7450
# odeint iter: 7460
# odeint iter: 7470
# odeint iter: 7480
# odeint iter: 7490
# odeint iter: 7500
# odeint iter: 7510
# odeint iter: 7520
# odeint iter: 7530
# odeint iter: 7540
# odeint iter: 7550
# odeint iter: 7560
# odeint iter: 7570
# odeint iter: 7580
# odeint iter: 7590
# odeint iter: 7600
# odeint iter: 7610
# odeint iter: 7620
# odeint iter: 7630
# odeint iter: 7640
# odeint iter: 7650
# odeint iter: 7660
# odeint iter: 7670
# odeint iter: 7680
# odeint iter: 7690
# odeint iter: 7700
# odeint iter: 7710
# odeint iter: 7720
# odeint iter: 7730
# odeint iter: 7740
# odeint iter: 7750
# odeint iter: 7760
# odeint iter: 7770
# odeint iter: 7780
# odeint iter: 7790
# odeint iter: 7800
# odeint iter: 7810
# odeint iter: 7820
# odeint iter: 7830
# odeint iter: 7840
# odeint iter: 7850
# odeint iter: 7860
# odeint iter: 7870
# odeint iter: 7880
# odeint iter: 7890
# odeint iter: 7900
# odeint iter: 7910
# odeint iter: 7920
# odeint iter: 7930
# odeint iter: 7940
# odeint iter: 7950
# odeint iter: 7960
# odeint iter: 7970
# odeint iter: 7980
# odeint iter: 7990
# odeint iter: 8000
# odeint iter: 8010
# odeint iter: 8020
# odeint iter: 8030
# odeint iter: 8040
# odeint iter: 8050
# odeint iter: 8060
# odeint iter: 8070
# odeint iter: 8080
# odeint iter: 8090
# odeint iter: 8100
# odeint iter: 8110
# odeint iter: 8120
# odeint iter: 8130
# odeint iter: 8140
# odeint iter: 8150
# odeint iter: 8160
# odeint iter: 8170
# odeint iter: 8180
# odeint iter: 8190
# odeint iter: 8200
# odeint iter: 8210
# odeint iter: 8220
# odeint iter: 8230
# odeint iter: 8240
# odeint iter: 8250
# odeint iter: 8260
# odeint iter: 8270
# odeint iter: 8280
# odeint iter: 8290
# odeint iter: 8300
# odeint iter: 8310
# odeint iter: 8320
# odeint iter: 8330
# odeint iter: 8340
# odeint iter: 8350
# odeint iter: 8360
# odeint iter: 8370
# odeint iter: 8380
# odeint iter: 8390
# odeint iter: 8400
# odeint iter: 8410
# odeint iter: 8420
# odeint iter: 8430
# odeint iter: 8440
# odeint iter: 8450
# odeint iter: 8460
# odeint iter: 8470
# odeint iter: 8480
# odeint iter: 8490
# odeint iter: 8500
# odeint iter: 8510
# odeint iter: 8520
# odeint iter: 8530
# odeint iter: 8540
# odeint iter: 8550
# odeint iter: 8560
# odeint iter: 8570
# odeint iter: 8580
# odeint iter: 8590
# odeint iter: 8600
# odeint iter: 8610
# odeint iter: 8620
# odeint iter: 8630
# odeint iter: 8640
# odeint iter: 8650
# odeint iter: 8660
# odeint iter: 8670
# odeint iter: 8680
# odeint iter: 8690
# odeint iter: 8700
# odeint iter: 8710
# odeint iter: 8720
# odeint iter: 8730
# odeint iter: 8740
# odeint iter: 8750
# odeint iter: 8760
# odeint iter: 8770
# odeint iter: 8780
# odeint iter: 8790
# odeint iter: 8800
# odeint iter: 8810
# odeint iter: 8820
# odeint iter: 8830
# odeint iter: 8840
# odeint iter: 8850
# odeint iter: 8860
# odeint iter: 8870
# odeint iter: 8880
# odeint iter: 8890
# odeint iter: 8900
# odeint iter: 8910
# odeint iter: 8920
# odeint iter: 8930
# odeint iter: 8940
# odeint iter: 8950
# odeint iter: 8960
# odeint iter: 8970
# odeint iter: 8980
# odeint iter: 8990
# odeint iter: 9000
# odeint iter: 9010
# odeint iter: 9020
# odeint iter: 9030
# odeint iter: 9040
# odeint iter: 9050
# odeint iter: 9060
# odeint iter: 9070
# odeint iter: 9080
# odeint iter: 9090
# odeint iter: 9100
# odeint iter: 9110
# odeint iter: 9120
# odeint iter: 9130
# odeint iter: 9140
# odeint iter: 9150
# odeint iter: 9160
# odeint iter: 9170
# odeint iter: 9180
# odeint iter: 9190
# odeint iter: 9200
# odeint iter: 9210
# odeint iter: 9220
# odeint iter: 9230
# odeint iter: 9240
# odeint iter: 9250
# odeint iter: 9260
# odeint iter: 9270
# odeint iter: 9280
# odeint iter: 9290
# odeint iter: 9300
# odeint iter: 9310
# odeint iter: 9320
# odeint iter: 9330
# odeint iter: 9340
# odeint iter: 9350
# odeint iter: 9360
# odeint iter: 9370
# odeint iter: 9380
# odeint iter: 9390
# odeint iter: 9400
# odeint iter: 9410
# odeint iter: 9420
# odeint iter: 9430
# odeint iter: 9440
# odeint iter: 9450
# odeint iter: 9460

# %%
print('Final accuracy on test dataset: {} %'.format(m.pred_accuracy(testloader)))
# Out:
# Final accuracy on test dataset: 0.9128 %
